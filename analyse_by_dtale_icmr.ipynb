# %%
import psycopg2
# import pandas as pd

# %%
conn = psycopg2.connect(
database="icmr_covid_db", user = "postgres", password = "veryvery" , host = "127.0.0.1")
# df = pd.read_sql_query('select * from icmrcoviddetails limit 100000', conn)
cursor = conn.cursor()

cursor.execute('''select icmr_id from icmrcoviddetails where testing_kit_used like '%PCR%' order by user_id asc limit 100000''')
result = cursor.fetchall()

# %%
from collections import Counter
d= Counter(result)
n = 0 
for a , b in dict(d).items():
    if b > 1:
        n += 1

while (True):
    initial_input = input('if you want to see total no. of duplicates , type yes : ')
    if initial_input == 'yes' :
        print(n)
        while (True):
            show_duplicate = input('for showing duplicates value , type yes : ')
            if show_duplicate == 'yes':
                for a , b in dict(d).items():
                    if b > 1:
                        print(a , ":", b)
                break
            else:
                print('wrong input for showing values of duplicates')
        break

    else :
        print('please put valid statement')

# %%
from collections import Counter
d= Counter(result)
print(len(d))

new_dict = {}
for a, b in dict(d).items():
    if b not in new_dict:
        new_dict[b] = 1
    else:
        new_dict[b] += 1

ord_dict = {}
for a,b in sorted(new_dict.items()):
    ord_dict[f'No. of Patients tested {a} times'] = b 
    
for a , b in ord_dict.items():
    print(a, ":", b)

# %%
from collections import Counter
from datetime import datetime
import operator
d= Counter(result)
n = 0 
for a , b in dict(d).items():
    if b > 1:
        n += 1

while (True):
    initial_input = input('if you want to see total no. of duplicates , type yes : ')
    if initial_input == 'yes' :
        print(n)
        while (True):
            show_duplicate = input('for showing duplicates value , type yes : ')
            if show_duplicate == 'yes':

                for a , b in dict(d).items():
                    if b > 2:
#                         print(type(a))
                        cursor.execute(f"select date_sample_collection from icmrcoviddetails where icmr_id = '{''.join(a)}' ")
                        result_1 = cursor.fetchall()
                        dates_1 =[]
                        for i in result_1:
                                       x = (''.join(i))
#                                        print('xxx :', x)
                                       y = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
#                                        print('yyyyy: ', y)
                                       dates_1.append(y)
                        dates_1.sort()
                        res = list(map(operator.sub, dates_1[1:], dates_1[:-1]))
                        print('--------------------------')
                        print(dates_1)
                        print(str(res))
                        
                break
            else:
                print('wrong input for showing values of duplicates')
        break

    else :
        print('please put valid statement')

# %%
from collections import Counter
from datetime import datetime
import operator

d= Counter(result)
new_dict = {}
initial_input =  input('Patinet with minimum duplicate values : ')
n = 0
for a, b in dict(d).items():
    if b >= int(initial_input):
        n += 1
print(n)


showing_duplicate = input('if you want to see duplicate patients type yes : ')
if showing_duplicate == 'yes':
    show_dict = {}
    for a, b in dict(d).items():
        if b >= int(initial_input):
            if b not in show_dict:
                show_dict[b] = 1
            else:
                show_dict[b] += 1

    ord_dict = {}
    for a,b in sorted(show_dict.items()):
        ord_dict[f'No. of Patients tested {a} times'] = b 

    for a , b in ord_dict.items():
        print(a, ":", b)

days_input= input('atleast how many days gap you want : ')
    
for a , b in dict(d).items():
                    if b >= int(initial_input):
#                         print(type(a))
                        cursor.execute(f"select date_sample_collection from icmrcoviddetails where icmr_id = '{''.join(a)}' ")
                        result_1 = cursor.fetchall()
                        
                        dates_1 = []
                        for i in result_1:
                                       x = (''.join(i))
#                                        print('xxx :', x)
                                       y = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
#                                        print('yyyyy: ', y)
                                       dates_1.append(y)
                        dates_1.sort()
#                         print(dates_1)
                        dates_2 =[]
                        for (i , j)  in zip(dates_1[1:], dates_1[:-1]):
#                                        print(i ,'----',j)
                                       c= i-j
#                                        print(c.days)
                                       if c.days <= int(days_input):
                                           dates_2.append(j.strftime('%Y/%m/%d'))
                                           dates_2.append(i.strftime('%Y/%m/%d'))
                        new_dict[''.join(a)]= dates_2
#                         print(new_dict)
for a , b in new_dict.items():
    print(a,' : ',b)

# %%
conn.close()
del cursor

# %%
from collections import Counter
from datetime import datetime
import operator
initial_input =  input('Patinet with how many tests : ')
second_input = int(input('within how many days you want : '))
d= Counter(result)
for a , b in dict(d).items():
                    if b >= int(initial_input):
#                         print(type(a))
                        cursor.execute(f"select date_sample_collection, testing_kit_used  from icmrcoviddetails where icmr_id = '{''.join(a)}' and testing_kit_used like '%PCR%' ")
                        result_1 = cursor.fetchall()
#                         if result_1 != []:
#                             print('yoyo' , result_1)
#                         else :
#                                        print('empty')
                        dates_1 = []
                        for i in result_1:
                                       x = (''.join(i))
#                                        --------------print('xxx :', x)
                                       y = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
                                       ----------print('yyyyy: ', y)
                                       dates_1.append(y)
                        dates_1.sort()
                        print(dates_1)
#                         --------print(dates_1)
                        n = 0
                        for (i , j)  in zip(dates_1[1:], dates_1[:-1]):
                           print(i ,'----',j)
                           n +=1
                           c= i-j 
                           print(c, 'outer days')  
                           if c.days<=second_input:
                                print(n,'first')
                                days_count=1
                                for i in dates_1[n:]:
                                    cc = i-dates_1[n-1]
                                    print(cc ,'internal days')   
                                    if cc.days > second_input:
                                       break
                                    elif cc.days<=second_input:
                                        days_count+=1
                                        print(i,'--',dates_1[n-1],'::',cc)
                                        print('daysdddddddddd',days_count)
                                    if days_count==int(initial_input):
                                        print(''.join(a),days_count)
                                        break       
                                if days_count == int(initial_input):
                                    break

# %%
# conn = psycopg2.connect(
# database="icmr_covid_db", user = "postgres", password = "veryvery" , host = "127.0.0.1")
# # df = pd.read_sql_query('select * from icmrcoviddetails limit 100000', conn)
# cursor = conn.cursor()

cursor.execute('''select "testing_kit_used" from icmrcoviddetails where testing_kit_used like '%PCR%' ''')
result = cursor.fetchall()

from collections import Counter
d= Counter(result)
print(len(d))
for a,b in dict(d).items():
    print(a)

# new_dict = {}
# for a, b in dict(d).items():
#     if b not in new_dict:
#         new_dict[b] = 1
#     else:
#         new_dict[b] += 1

# ord_dict = {}
# for a,b in sorted(new_dict.items()):
#     ord_dict[f'No. of Patients tested {a} times'] = b 
    
# for a , b in ord_dict.items():
#     print(a, ":", b)
# Out:
# 48
# ('Liferiver_RTPCR',)
# ('POCT_Q-line_RTPCR_kit',)
# ('Medsource_RTPCR',)
# ('GB SARS-CoV-2 Real-Time RT-PCR kit',)
# ('Meril_RTPCR',)
# ('Detection Expert 1S © SARS CoV-2 One Step RT-PCR Kit',)
# ('True_PCR_Kelpest',)
# ('qPCR kit',)
# ('Covisure COVID 19 Real time PCR kit',)
# ('Meril COVID19 One-step RT-PCR Kit',)
# ('TRUPCR SARS COV2',)
# ('PROMEA THERAPEUTICS PRO PCR CORONA RT Q-PCR',)
# ('LabGun COVID-19 ExoFast RT-PCR KIT',)
# ('CoviPath Covid 19 RT PCR Kit',)
# ('COVID-19 RT-PCR kit',)
# ('Hi-PCR® Coronavirus (COVID-19) Multiplex Probe PCR Kit',)
# ('ANGPCR COVID-19',)
# ('Fosun_nCoV_qPCR',)
# ('Viral Detect II Multiplex Realtime RTPCR for COVID',)
# ('CoviPath_RTPCR_Thermofisher',)
# ('GenePath CoVidx One RT-qPCR v2.1.1',)
# ('GeneStore Detection Expert 1STEP SARS CoV-2 RRT-PCR KIT',)
# ('LyteStar 2019-nCoV RT-PCR Kit 2.0',)
# ('GB_SARS_RTPCR_kit',)
# ('Black_Bio_Biotech_TRUPCR',)
# ('Qline_MER_RTPCR_PICT_ltd',)
# ('COVSCAN_RTPCR_NextGen_Invitro_Diag',)
# ('Angstrom_ANGPCR_2019-nCoV',)
# ('Hi_PCR_Himedia',)
# ('Accusa_RTPCR_Mesa_Biotech_Thermofischer',)
# ('QuantuMDx_SARS-CoV-2_RT-PCR',)
# ('Shenzen_Real_Time_PCR_Kit',)
# ('Helini_Biomolecules_Covid_PCR_kit',)
# ('Medsource_Ozone_RT-PCR',)
# ('Helini_Biomolecules_RTPCR_kit',)
# ('IITD_RTPCR_kit',)
# ('Lipomic_multiplex_RTPCR',)
# ('ProPCR_RTqPCR_promea_therapeutics',)
# ('Gene_Proof_SARS-CoV-2_PCR',)
# ('ARS_RTPCR_QIAGEN_GmbH',)
# ('Vitro_SARS-CoV-2_RT-PCR_Kit',)
# ('True PCR  Kelpest',)
# ('Meril COVID19 One-step RTPCR kit',)
# ('DNA_Xpert_Covido19_RTPCR_kit',)
# ('VIASURE_RTPCR',)
# ('Nucleus_SARS_CoV-2_Triplex_PCR',)
# ('SARS-CoV-2 RT-qPCR Reagent Kit 9',)
# ('Solgent_Diaplex_Q_RTPCR',)
